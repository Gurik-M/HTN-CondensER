# %%
import cohere
import pandas as pd
import requests
import datetime
from tqdm import tqdm
pd.set_option('display.max_colwidth', None)

def get_post_titles(**kwargs):
    """ Gets data from the pushshift api. Read more: https://github.com/pushshift/api """
    base_url = f"https://api.pushshift.io/reddit/search/submission/"
    payload = kwargs
    request = requests.get(base_url, params=payload)
    return [a['title'] for a in request.json()['data']]

api_key = 'WEzAHVi3WSNaGJdsHGkEPreheqssa0ihmCXc7Kx4'

co = cohere.Client(api_key)


symptoms_examples = [
("none", "Could you please tell me what it is!"),
("chest pain", "Chest pain!"),
("blurred vision, headaches", "Occasionally blurred vision with headaches"),
("food poisoning", "I think I may have some minor food poisoning of some sorts"),
("fingers shaking", "My fingers won't stop shaking!"),
("nausea and dry mouth", "Sudden onset of nausea and dry mouth"),
]

# %%
class cohereExtractor():
    def __init__(self, examples, example_labels, labels, task_desciption, example_prompt):
        self.examples = examples
        self.example_labels = example_labels
        self.labels = labels
        self.task_desciption = task_desciption
        self.example_prompt = example_prompt

    def make_prompt(self, example):
        examples = self.examples + [example]
        labels = self.example_labels + [""]
        return (self.task_desciption +
                "\n---\n".join( [examples[i] + "\n" +
                                self.example_prompt + 
                                 labels[i] for i in range(len(examples))]))

    def extract(self, example):
      extraction = co.generate(
          model='large',
          prompt=self.make_prompt(example),
          max_tokens=10,
          temperature=0.1,
          stop_sequences=["\n"])
      return(extraction.generations[0].text[:-1])


cohereMovieExtractor = cohereExtractor([e[1] for e in symptoms_examples], 
                                       [e[0] for e in symptoms_examples], [],
                                       "", 
                                       "extract the symptoms from the post:")

print(cohereMovieExtractor.make_prompt('<input text here>'))
# Out:
# Could you please tell me what it is!
# extract the symptoms from the post:none
# ---
# Chest pain!
# extract the symptoms from the post:chest pain
# ---
# Occasionally blurred vision with headaches
# extract the symptoms from the post:blurred vision, headaches
# ---
# I think I may have some minor food poisoning of some sorts
# extract the symptoms from the post:food poisoning
# ---
# My fingers won't stop shaking!
# extract the symptoms from the post:fingers shaking
# ---
# Sudden onset of nausea and dry mouth
# extract the symptoms from the post:nausea and dry mouth
# ---
# <input text here>
# extract the symptoms from the post:

# %%
num_posts = 100

symptoms_list = get_post_titles(size=num_posts, 
      after=str(int(datetime.datetime(2015,1,1,0,0).timestamp())), 
      before=str(int(datetime.datetime(2020,1,1,0,0).timestamp())), 
      subreddit="medical_advice", 
      sort_type="score", 
      sort="desc")

# Show the list
symptoms_list
# Out:
# ['This felt like it belonged',
#  'FOR THE LOVE OF ALL THINGS HOLY PLEASE USE THE NSFW TAG FOR GROSS THINGS',
#  'Which would it be?',
#  'My mom send me this pic- she’s 100 miles away from a Dr. 63, F, smoker, alcoholic',
#  "This mark appeared on my 2 week old a few days ago, any ideas as to what it is ? Her pediatrician canceled our schedule til Wednesday and I'm getting impatient.",
#  'My cut stopped bleeding them dramatically picked up??',
#  'Contact dermatitis or something more serious?',
#  "Cut myself on rocks, won't heal after over a month. Poor college student, can't afford health insurance. Need more advice.",
#  'Not Your Average Bald spot... What the FUCK is this?',
#  'Jabbing feeling on right side of head. Lasts a couple of seconds and sometimes I feel paralysed during the pain. Should I be worried?',
#  'Scrapped my knee two days ago. Cleaned it then and applied a bandage. Removed it today to clean it and bandage it. Is this normal? or is it infected?',
#  'F 18 97lbs. Duration of complaint: 3 months. This scar on my chest often has sharp pain that causes heart palpitations. How do I treat it?',
#  'Why is there an orange spot next to my pupil (ever since I was born)',
#  'What is this in my moms eye?',
#  'Every couple of months when I exercise, my eyes swell up, both exercising inside and outside. The only conclusion I\'ve gathered is my eyes have a reaction to my sweat? What gives?! F23, 130lbs, 5\'7", white, no prescriptions, allergic to penicillin, no drug use, and no makeup is on when I workout.',
#  'HELP MY PENIS',
#  'Just wondering what’s going on here. I used some allergy relief eye drops with pheniramine maleate and naphazoline hydrochloride in it. Is this just a side effect of the drops? Hopefully?',
#  'Concerned Father.',
#  'Why do I even bother going?',
#  "Anyone? My doc seems to think it's due to excessive sweating. It's not",
#  "How do I clean and dress this large burn? I think it's infected",
#  'My wife (F29) sliced off part of her finger nail while chopping vegetables and we were just wondering what the best course of action was. Should we keep it totally dry and wrapped? How long does it take to grow back?',
#  'Do I need to seek medical help?',
#  'Hit in the face, now turning into a dragon...',
#  'My pituitary tumor :/ i also have two thyroid nodules',
#  "Why are my nails suddenly like this? How can I make them go back to normal? They are clean in this pic. 30f, non smoker, on bipolar meds but that's not new.",
#  '21 M, 6’ 225 lbs Caucasian. Marijuana occasionally, drinking heavier last month (symptoms before that). Have dandruff, but this patch created large pieces (not flakes). Recently shaved and discovered the patch (no large dandruff from patch since shave though). What is it?',
#  'Why do doctors dismiss women in pain as dramatic or crazy?',
#  'Found a lump- get it checked!',
#  'Post-drained and irrigated felon infection question. I have an appointment in a week. My finger doesn’t hurt but it looks worrying. I recently ran out of the ER antibiotic prescriptions. Should I wait for my appointment or go back to the ER to get back on my antibiotics ASAP?',
#  'Anyone know why I would just have a mystery bruise like this? Upper calf, I have no recollection of hitting this area at all. Looks like a bite but I’m assuming those are old stretch marks.',
#  'I fell off a skateboard today and hurt my toe I’m just curious if there is anyway to tell if it’s just sprained or broken.',
#  'I have been trying to find a name, or similar case of this type of jaw problem with no success, what is it called?',
#  'My grandma (80yo) broke her back 2 months ago from falling down and was prescribed getting out of bed twice a day. Is this normal?',
#  'Compressed chemical burn, should I seek the help of my doctor?',
#  'My skin keeps ripping near the head of my penis during sex.',
#  'Could this be throat cancer, if not what else could it be.(this is in the back of my throat)',
#  'Why is my spine always showing?',
#  'Pacemaker Replacement... Does this look infected?',
#  'I have this strange rash all over my body especially in the genital area, does anyone know what it is?',
#  'Fell on the side walk ripped the skin on my palm 1.5 days ago. I put Neosporin on it but it’s still kind of yellow. Is it infected or is this how it normally heals?',
#  'Why are my hands like thus when I only just hit my thirties?',
#  'Skeletal Deformity?',
#  'What is this? I’m 16 so it can’t be arthritis or anything.',
#  'During scan of my abdomen, 2 doctors asked me if I had ever had surgery (I have not) Why would they ask/what did they think they saw?',
#  'I cut my finger about 5 days ago. The picture on the left is how it looks now. Does it look healthy?',
#  'Having a lot of unexplained neurological symptoms that are getting worse but so far today is the worst it’s ever been and I’m wondering if I should go to the doctor today about it.',
#  'Have this red bump growing on the inside of my cheek any knowledge what this might be',
#  "NSFW had a problem down there and doctors don't know what was wrong",
#  'I gave my blood and 1 week later I have this, is this normal?',
#  'Help! It itches and is spreading. OTC creams are useless. What is this??',
#  'Nuva Ring in Bladder - looking for ideas how it got there',
#  'Penis related problem',
#  "PLEASE HELP. Found lump on my scalp. I've always felt it on the back of my head but only now i could see it since mom felt it too and looked at it. Could this cancerous? I've had it since i was little and i don't think it changed size too much. What could this be? Please, we're panicking...",
#  'Gap in corner of eye on the right side of the picture. What is this? Is it dangerous?',
#  'Mysterious bruise on my back - what could this be from? (Nothing out of the norm past week and yes i have been 100% sober) F25, active, healthy, non drug user.',
#  'Could I be allergic to my boyfriend? [NSFW]',
#  'Evenly spaced red dots of broken blood vessels on boyfriend’s back, trying to find a non-UFO related explanation',
#  'Dropped a heavy load on toe five months ago; should I remove or wait',
#  'Some advice for many people here',
#  'Is masturbation bad for the penis?',
#  'I have diabetes been drinking a liter of vodka redbull a day my wounds won’t heal and they emerge on their own',
#  'My roommates cat attacked me on Tuesday last week. It’s tender to the touch and a bit raised.',
#  'What is this on baby’s leg?',
#  'Can’t see my actual butthole, had these for years, big enough for surgical removal?',
#  'is it necessary to go to the hospital? this happened 2 days ago. I fell, it kinda hurts. I have kept it bandaged and stuff kinda and also have put antibiotic cream on it but it keeps bleeding at times, like rn. (19M) picture taken just now.',
#  'Blood in my eyeball. It kinda looks like there’s blood filling my left eye. I’m not in any pain but I’ve never seen anything like this before.',
#  'Accidentally took estrogen',
#  'Retaining alot of water in my hands',
#  'Black mosquito bite. An article said it might be leukemia and I can find anything else. My health anxiety is going trough the roof right now what should I do.',
#  "I was going to sleep but I felt something in my eye. I thought it might of been dust or an eyelash but after trying to wash it out for 30 minutes It felt like it didn't budge so decided to try and take a photo of my eye to see what it is. The flash made out a very tiny bump. What is this???",
#  'Posted yesterday and many of you said to see a doctor so I did...',
#  'Sometimes extreme tiredness will hit me and I feel like if I don’t immediately sleep, I’ll pass out. 10-15 minutes of sleep and I’ll be fine.',
#  'Always listen to your body',
#  'I’ve had this for 6 months, thought it was an ingrown hair and I’ve been waiting for the hair to come out but it didn’t, now I’m not so sure what it is. Any ideas?',
#  'NSFW embarassing...but i have a problem wirh premature ejaculation...',
#  'is this a fungus?? how can i get rid of it? i don’t know the cause',
#  '[Serious] my ex drew in anger on me and i got a cut in which sharpie got it. It’s been like this for 8 months... How can I get rid of it? Its too close to my eye to laser.',
#  'My friend noticed this small red circle on her leg today, possibly lyme? More info in the comments!',
#  'Just a little off the tip?',
#  "Can't remove marker paint. More in comments",
#  'Can Debrox (carbamide peroxide) burn ear canal?',
#  'NSFW. This black and reddish dot appeared on my penis like overnight. What is this?',
#  'Can someone please help. Idk what this is. It’s been getting worse. Also I just got out of the shower that’s why my hands are all pruned lol',
#  'Noticed small red dots on either arm in almost exact same areas. No pain, but with family history of skin cancer my mind jumps to the worst conclusion. Should I see a doctor or just watch and document it? For reference, 26 female, teacher/ outdoor guide. No tick bites.',
#  'A cutting board hit my toe 3 hours ago, it bled. Do I need to see a doctor?',
#  'Just found my tampon after weeks, should I see my doctor?',
#  'My brother suddenly fell',
#  'Discoloured discharge from my eye - does this look normal? Flagged as urgent because I wear contacts',
#  'Do I Have Psychosis?',
#  "I've been working on a dirty linefishing boat for 2 weeks, have scabs like this all over my hands and can hardly move them, what should i do?",
#  'Please help me I’m scared',
#  "Purple stripes on upper arms, I dont exercise, so I doubt it's growth scars.",
#  'So this is day three. I’m on antibiotics 4 times a day (from yesterday) but this evening my swelling has double in size, should I be worried about Sepsis? I also have a Low temp, but normal heart rate. The bite was a horsefly.',
#  "Ive had this sore on my nose for about 8-9 days. Its been leaking clear fluid that crusts over. Note that I do wear glasses, but im not sure if they rub on the area too much or not. It doesn't hurt but I dont know if I should go to quick care for it or not. Help?",
#  'I have this gaping cut on my finger and I don’t know what to do next. I cleaned it and bandaged it up but I don’t know if I should do anything else. I held it open so you could see how deep it is. I can’t go to a hospital I’m a selfharmer and I slipped and hit my finger. I’m scared they’ll admit me.',
#  'Sometimes I’ll be going about my business and then I’ll suddenly feel like I’m not me. It is hard to explain. I feel like my head is floating and like I’m observing myself doing things. It’s not out of body, it’s more like I’m looking out from myself. Needless to say it’s disturbing.',
#  'I have a lump under my testicles',
#  'Do I have Skittles Pox? Urgent Care said hives but it’s been 24 hours and 110 MB’s of Prednisone and 100mg of Benadryl and it’s still getting worse.',
#  'Have I broken my toe?']

# %%
results = []
for text in tqdm(symptoms_list):
    try:
        extracted_text = cohereMovieExtractor.extract(text)
        results.append(extracted_text)
    except Exception as e:
        print('ERROR: ', e)
# Out:
# 100%|█████████████████████████████████████████| 100/100 [01:10<00:00,  1.41it/s]

# %%
pd.DataFrame(data={'text': symptoms_list, 'extracted_text': results})
# Out:
#                                                                                                                                                                                                                                                                                                             text  \
# 0                                                                                                                                                                                                                                                                                     This felt like it belonged
# 1                                                                                                                                                                                                                                       FOR THE LOVE OF ALL THINGS HOLY PLEASE USE THE NSFW TAG FOR GROSS THINGS
# 2                                                                                                                                                                                                                                                                                             Which would it be?
# 3                                                                                                                                                                                                                              My mom send me this pic- she’s 100 miles away from a Dr. 63, F, smoker, alcoholic
# 4                                                                                                                                               This mark appeared on my 2 week old a few days ago, any ideas as to what it is ? Her pediatrician canceled our schedule til Wednesday and I'm getting impatient.
# ..                                                                                                                                                                                                                                                                                                           ...
# 95  I have this gaping cut on my finger and I don’t know what to do next. I cleaned it and bandaged it up but I don’t know if I should do anything else. I held it open so you could see how deep it is. I can’t go to a hospital I’m a selfharmer and I slipped and hit my finger. I’m scared they’ll admit me.
# 96                  Sometimes I’ll be going about my business and then I’ll suddenly feel like I’m not me. It is hard to explain. I feel like my head is floating and like I’m observing myself doing things. It’s not out of body, it’s more like I’m looking out from myself. Needless to say it’s disturbing.
# 97                                                                                                                                                                                                                                                                              I have a lump under my testicles
# 98                                                                                                                                                          Do I have Skittles Pox? Urgent Care said hives but it’s been 24 hours and 110 MB’s of Prednisone and 100mg of Benadryl and it’s still getting worse.
# 99                                                                                                                                                                                                                                                                                         Have I broken my toe?
#
#                 extracted_text
# 0   this felt like it belonged
# 1                         none
# 2                         none
# 3                         none
# 4                         mark
# ..                         ...
# 95               cut on finger
# 96                 out of body
# 97        lump under testicles
# 98                skittles pox
# 99                  broken toe
#
# [100 rows x 2 columns]
